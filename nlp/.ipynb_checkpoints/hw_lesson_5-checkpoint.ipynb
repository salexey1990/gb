# %%
import pandas as pd
from string import punctuation
from stop_words import get_stop_words
from pymorphy2 import MorphAnalyzer
import re
import nltk
from nltk.tokenize import word_tokenize
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score

import numpy as np
import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Input, Embedding, Conv1D, GlobalMaxPool1D
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.callbacks import TensorBoard 
from keras.objectives import categorical_crossentropy
from keras.callbacks import EarlyStopping

# %%
max_words = 2000
max_len = 40
num_classes = 1

# Training
epochs = 20
batch_size = 512
print_batch_n = 100

# %%
data = pd.read_excel("/home/alex/Downloads/nlp/5/отзывы за лето.xls")

# %%
data.head()
# Out:
#    Rating                                            Content        Date
# 0       5                                     It just works!  2017-08-14
# 1       4  В целом удобноное приложение...из минусов хотя...  2017-08-14
# 2       5                                        Отлично все  2017-08-14
# 3       5  Стал зависать на 1% работы антивируса. Дальше ...  2017-08-14
# 4       5                     Очень удобно, работает быстро.  2017-08-14

# %%
exclude = set(punctuation)
sw = set(get_stop_words("ru"))
morpher = MorphAnalyzer()

def preprocess_text(txt):
    txt = str(txt)
    txt = "".join(c for c in txt if c not in exclude)
    txt = txt.lower()
    txt = re.sub("\sне", "не", txt)
    txt = [morpher.parse(word)[0].normal_form for word in txt.split() if word not in exclude]
    return " ".join(txt)

data['text'] = data['Content'].apply(preprocess_text)
data = data[data['Rating'] != 3]
data['target'] = data['Rating'] > 3

# %%
data['target'] = data['target'].astype(int)
data.head()
# Out:
#    Rating                                            Content        Date  \
# 0       5                                     It just works!  2017-08-14
# 1       4  В целом удобноное приложение...из минусов хотя...  2017-08-14
# 2       5                                        Отлично все  2017-08-14
# 3       5  Стал зависать на 1% работы антивируса. Дальше ...  2017-08-14
# 4       5                     Очень удобно, работает быстро.  2017-08-14
#
#                                                 text  target
# 0                                      it just works       1
# 1  в целое удобноной приложениеиз минус хотеть сл...       1
# 2                                       отлично весь       1
# 3  стать зависать на 1 работа антивирус далёкий н...       1
# 4                       очень удобно работать быстро       1

# %%
X_train, X_test, y_train, y_test = train_test_split(data['text'], data['target'], test_size=0.2,
                                                    random_state=13, stratify=data['target'])

# %%
train_corpus = " ".join(X_train)
train_corpus = train_corpus.lower()

# %%
train_corpus
# Out:
# 'классно невозможно использовать на рутованный телефон работать хорошо без нарекание отлично ян мочь понять почему заблокировать мой аккаунт классный приложение очень удобный в использовании👍 постоянно запускаться сам при запуск программа или игра бесить и напрягать удалить удобный приложение позволять в мгновение око выполнить перевод средство пополнить баланс телефон и просто смотреть сумма на карта удобно надёжно приятно отличный приложение и отдельный спасибо антивирус очень удобно когда под рука находиться мобильный банкперевод деньга можно осущесьалятьня выходить из дом весь огонь нормальный приложение довольно удобно с пиво попрать не мочь установить после вирус самый нужный приложение в мыть телефон безний как без рука весь ок удобноработать без зависанийя давольный работа это приложение im not happy with the app it lags and and not user friendly it should make life easy instead it creates more problems очень удобно спасибо только приходиться отключать антивирус чтобы зайти в приложение отлично работаетспасибо очень просто и удобно norm простой и удобный чем сбербанк онлайн функционал хватать какаять муть с копилка платёж пара днейн совершать но почемуть на копилка деньга переводиться и ещё минус нет досрочный погашение кредит только через комп если честно дерьмо ваш приложение исправить весь баг наконец не позориться хорошо спасибо я нравиться весь супер благодарный вы за столь чудесный преложение я очень любить вы ваш банк самый хороший и удобный для начало пользование отлично далёкий пожить увидеть красавчик дрянь работать через раз и танец с бубен nexus 6p весь нравитсявсё удобно приложение постоянно вылетать с страница приветствие телефон xiaomi redmi 4x прошивка оригинал без рута я довольный дать система отлично спасибо нормальный удобный программа удобный пользоваться долго без нарекание но после обнова ругаться на рута а в урезанный версиинуть смысл удалять замечательный приложение весь отлично очень удобный приложение весь удобно и понятно спасибо приложение открываться сам по себя надоесть я нравиться очень удобный и функциональный приложение позволять управлять счетамин ходить в сбербанк иня тратить свой время почемуна отображаться карта очень удобный программка быстро удобно и функционально не мочь скачать писать код ошибка 941 хороший лёгкое и удобный приложение отличный приложение достаточно удобно пишетний удаться антивирус далее продолжить и вылет очень удобно и быстро делать перевод зачем приложение каждый раз сканировать прошивка целый история зайти в приложение и 5050 после вход оно снова скидывать на ввод пароль удобно и быстро вполне удобный приложение интерфейс интуитивный платёж история весь под рука норма илья раман круто спасибо за ответ не возможно использовать приложение через спутниковый интернет без доступ к gsm станция например в открытый мореразработчик развиваетесть прекрасный приложение lidia приложение стать работать медленно отлично работать не знать насколько безопасно но очень удобно и быстро очень хороший и удобный программа приложение нравиться очень удобно замечанийнуть я весь устраивать спасибо большой очень удобный приложение спасибовсё отлично работаетмна весь нравится👍 только начать пользоваться мобильный банк и вполне удобный приложение конечно почитавнегативный комент о проблема связанный с мб понимать что ничто идеальногонет но и так сойти пока что так сойти для начало вот весь быстро работать и чётко удобно быстро действительно отличный приложение 😘 просто и лаконично грузиться долго требовать пин понесколька раз вылетать а сегодня один из карта просто исчезнуть класс очень удобнона надо лишний раз бежать в банк очень удобно и быстро пользуюсьнедавно пока весь устраивать спасибо за приложение ваш так называть антивирус в приложение ругаться на предустановленный сервис lenovo которыен отключаться изз этогон мочь ничто делать в приложение убрать наконец этот бессмысленный вещь весь супер спасибо огромный очень удобный приложение любить сбербанк почему у я он выдавать какуют ...

# %%
tokens = word_tokenize(train_corpus)

# %%
tokens_filtered = [word for word in tokens if word.isalnum()]

# %%
from nltk.probability import FreqDist
dist = FreqDist(tokens_filtered)
tokens_filtered_top = [pair[0] for pair in dist.most_common(max_words-1)]

# %%
tokens_filtered_top
# Out:
# ['приложение',
#  'весь',
#  'и',
#  'очень',
#  'удобно',
#  'в',
#  'я',
#  'на',
#  'работать',
#  'удобный',
#  'с',
#  'что',
#  'отлично',
#  'спасибо',
#  'нравиться',
#  'хороший',
#  'отличный',
#  'это',
#  'хорошо',
#  'телефон',
#  'по',
#  'супер',
#  'после',
#  'но',
#  'раз',
#  'мочь',
#  'быть',
#  'а',
#  'за',
#  'быстро',
#  'просто',
#  'обновление',
#  'при',
#  'пользоваться',
#  'как',
#  'так',
#  'у',
#  'антивирус',
#  'устраивать',
#  'вы',
#  'сбербанк',
#  'только',
#  'не',
#  'пароль',
#  'пока',
#  'карта',
#  'то',
#  'свой',
#  'нормальный',
#  'для',
#  'прошивка',
#  'вход',
#  'без',
#  'банк',
#  'из',
#  'рута',
#  'перевод',
#  'норма',
#  'есть',
#  'один',
#  'сделать',
#  'программа',
#  'деньга',
#  'разработчик',
#  'счёт',
#  'проблема',
#  'писать',
#  'время',
#  'ошибка',
#  'довольный',
#  'бы',
#  'ваш',
#  'можно',
#  'ок',
#  'платёж',
#  'или',
#  'к',
#  'мой',
#  'он',
#  'до',
#  'стать',
#  'другой',
#  'постоянно',
#  'приходиться',
#  'через',
#  'уже',
#  'два',
#  'понятно',
#  'вводить',
#  'если',
#  'этот',
#  'ещё',
#  'исправить',
#  'надо',
#  'нужно',
#  'тот',
#  'функция',
#  'долго',
#  'код',
#  'ни',
#  'возможность',
#  'такой',
#  'смс',
#  'теперь',
#  'зайти',
#  'большой',
#  'класс',
#  'делать',
#  'мобильный',
#  'право',
#  'последний',
#  'шаблон',
#  'всегда',
#  'какой',
#  'который',
#  'когда',
#  'иня',
#  'вылетать',
#  'самый',
#  'о',
#  'каждый',
#  'приходить',
#  'от',
#  'root',
#  'иногда',
#  'почему',
#  'meizu',
#  'установить',
#  'работа',
#  'проверка',
#  'же',
#  'заходить',
#  'онлайн',
#  'даже',
#  'молодец',
#  'оплата',
#  'нужный',
#  '5',
#  'версия',
#  'операция',
#  'функционал',
#  'банка',
#  'чем',
#  'доступ',
#  'они',
#  'круто',
#  'удалить',
#  'полный',
#  'пожалуйста',
#  'войти',
#  'вообще',
#  'приложениен',
#  'ввод',
#  'номер',
#  'под',
#  'рука',
#  'чтобы',
#  'хотя',
#  'ранний',
#  'клиент',
#  '2',
#  'ян',
#  'понравиться',
#  'изз',
#  'интернет',
#  'день',
#  'легко',
#  'вирус',
#  'целое',
#  'оплачивать',
#  'отпечаток',
#  'зачем',
#  'оно',
#  'дать',
#  'перестать',
#  'кредит',
#  'новый',
#  'первое',
#  'просить',
#  'дом',
#  'много',
#  'выдавать',
#  'запуск',
#  'убрать',
#  'главный',
#  'выходить',
#  'устройство',
#  'простой',
#  'вот',
#  'удалять',
#  'быстрый',
#  'сбер',
#  'сам',
#  'уведомление',
#  'год',
#  'минус',
#  'замечательный',
#  'никакой',
#  'ничегон',
#  'безопасность',
#  'плохо',
#  'оплатить',
#  'сразу',
#  'отзыв',
#  'классный',
#  'знать',
#  'добавить',
#  'ничто',
#  'часто',
#  'перевести',
#  'ждать',
#  'ввести',
#  'доступно',
#  'проверять',
#  'запускаться',
#  'интерфейс',
#  'оригинальный',
#  'дело',
#  'да',
#  'давать',
#  'там',
#  'ну',
#  'банкомат',
#  'открываться',
#  'скачать',
#  'видеть',
#  'кто',
#  'услуга',
#  'палец',
#  'история',
#  'снова',
#  'инициализация',
#  '3',
#  'сообщение',
#  'хотеть',
#  'полезный',
#  'себя',
#  'месяц',
#  'человек',
#  'сервис',
#  'использование',
#  'сейчас',
#  'финансы',
#  'идти',
#  'переводить',
#  '4',
#  'минута',
#  'баланс',
#  'вернуть',
#  'бесполезный',
#  'средство',
#  'управлять',
#  'заново',
#  'любой',
#  'устанавливаться',
#  'андроид',
#  'звезда',
#  'ставить',
#  'долгий',
#  'загружаться',
#  'зависать',
#  'пользователь',
#  'чётко',
#  'тормозить',
#  'думать',
#  'встроить',
#  'классно',
#  'попытка',
#  'общий',
#  'ужасный',
#  'смартфон',
#  'прога',
#  'контакт',
#  'связь',
#  'найти',
#  'прекрасно',
#  '10',
#  'грузиться',
#  'посмотреть',
#  'получаться',
#  'хотеться',
#  'обновить',
#  'вообщен',
#  '1',
#  'гуд',
#  'загрузка',
#  'прийтись',
#  'решить',
#  'сумма',
#  'помогать',
#  'тут',
#  'три',
#  'между',
#  'установка',
#  '24',
#  'куда',
#  'выкидывать',
#  'остальной',
#  'сказать',
#  'бывать',
#  'чтоня',
#  'где',
#  'потом',
#  'далёкий',
#  'кроме',
#  'вроде',
#  'рекомендовать',
#  'ли',
#  'настройка',
#  'входить',
#  'личный',
#  'худой',
#  'здорово',
#  'должный',
#  'понятный',
#  'она',
#  'вопрос',
#  'давно',
#  'надёжно',
#  'возможно',
#  'место',
#  'сайт',
#  'жизнь',
#  'советовать',
#  'ужасно',
#  'стабильно',
#  'регистрация',
#  'система',
#  'бесить',
#  'лишний',
#  'экономить',
#  'тупить',
#  'информация',
#  'дважды',
#  'нона',
#  'требовать',
#  'пин',
#  'мы',
#  'плохой',
#  'пропасть',
#  'вполне',
#  'смочь',
#  'полностью',
#  'оценка',
#  'написать',
#  'опять',
#  'приятно',
#  'начать',
#  'доступный',
#  'разобраться',
#  'предложение',
#  'глючить',
#  'пытаться',
#  'старый',
#  'запрашивать',
#  'чтоб',
#  'нет',
#  'экран',
#  'поставить',
#  'заработать',
#  'появиться',
#  'особенно',
#  'либо',
#  'этоня',
#  'единственный',
#  'ограничение',
#  'выручать',
#  'назад',
#  'сеть',
#  'ругаться',
#  'ужас',
#  'ана',
#  'момент',
#  'постоянный',
#  'отправить',
#  'тоже',
#  'стоить',
#  'потому',
#  'более',
#  'имя',
#  'память',
#  'менять',
#  'тк',
#  'логин',
#  'использовать',
#  'хватать',
#  'смысл',
#  'помочь',
#  'читать',
#  'android',
#  'очередь',
#  'официальный',
#  'кабинет',
#  'удобство',
#  'сбой',
#  'слово',
#  'ребята',
#  'отвратительный',
#  'обновлениян',
#  'раздражать',
#  'данный',
#  'браузер',
#  'устанавливать',
#  'чтоть',
#  'подтверждение',
#  'показывать',
#  'мыть',
#  'огромный',
#  'пять',
#  'приятный',
#  'радовать',
#  'мейза',
#  '6',
#  'бред',
#  'виснуть',
#  'практично',
#  'поэтому',
#  'совершать',
#  'безопасно',
#  'управление',
#  'висеть',
#  'находить',
#  'вклад',
#  'лично',
#  'платить',
#  'покан',
#  'хоть',
#  'многий',
#  'надеяться',
#  'сколько',
#  'соединение',
#  'штрихкод',
#  'сервер',
#  'держать',
#  'отключить',
#  'мало',
#  'открыть',
#  'жаль',
#  'получить',
#  'дажена',
#  'достаточно',
#  'глюк',
#  'samsung',
#  'защита',
#  'обновляться',
#  'почти',
#  'зарегистрироваться',
#  'банковский',
#  'иметь',
#  'копилка',
#  'ходить',
#  'косяк',
#  'говорить',
#  'расход',
#  'уважаемый',
#  'сильно',
#  'равно',
#  'происходить',
#  'список',
#  'проходить',
#  'про',
#  'отображаться',
#  'конечно',
#  'удобнона',
#  'самсунг',
#  'видно',
#  'стоять',
#  'крутой',
#  'note',
#  'набирать',
#  'намного',
#  'ограниченный',
#  'понимать',
#  'жкх',
#  'возникать',
#  'проверить',
#  'good',
#  'оперативно',
#  'планшет',
#  'нарекание',
#  'например',
#  'прекрасный',
#  'кнопка',
#  'ограничить',
#  '100',
#  'появляться',
#  'хрень',
#  'исправлять',
#  'выполнять',
#  'super',
#  'ты',
#  'обслуживание',
#  'тд',
#  'понять',
#  'пользование',
#  'страница',
#  'xiaomi',
#  'сегодня',
#  'принцип',
#  'сидеть',
#  'купить',
#  'обновлять',
#  'случай',
#  'понесколько',
#  'помощь',
#  'сканер',
#  'час',
#  'удаться',
#  'ответ',
#  'занимать',
#  'ok',
#  'действие',
#  'причина',
#  'исправт',
#  'качественно',
#  'какойтый',
#  'итог',
#  'открывать',
#  'подключение',
#  'половина',
#  'создать',
#  'файл',
#  'всего',
#  'пополнить',
#  'погашение',
#  'почемуна',
#  'pay',
#  'проблемень',
#  'наличие',
#  'друг',
#  'пинкод',
#  'грузить',
#  'плюс',
#  'подключить',
#  'скачивать',
#  'начинать',
#  'the',
#  'пара',
#  'redmi',
#  'новое',
#  'тем',
#  'хорошоя',
#  'прошивкан',
#  'тело',
#  'комиссия',
#  'секунда',
#  'удаление',
#  'скачиваться',
#  'повторный',
#  'меню',
#  'слишком',
#  'напрягать',
#  'почемуть',
#  'баг',
#  'открытый',
#  'вещь',
#  'нафиг',
#  'выбрасывать',
#  'заводский',
#  'm5',
#  'здравствовать',
#  '23',
#  'обратно',
#  'простон',
#  'выписка',
#  'отправлять',
#  'скорость',
#  'теперьня',
#  'авторизация',
#  'маленький',
#  'инуть',
#  'разраб',
#  'также',
#  'медленно',
#  'блокировать',
#  'здесь',
#  'квитанция',
#  'считать',
#  'раздел',
#  'тупой',
#  'урезать',
#  'мнен',
#  'тогда',
#  'меняня',
#  'срочно',
#  'автоплатёж',
#  'гораздо',
#  'отделение',
#  'удача',
#  'невозможно',
#  'позволять',
#  'досрочный',
#  'наконец',
#  'исчезнуть',
#  'следить',
#  'добрый',
#  'поддержка',
#  'установленный',
#  'компьютер',
#  'страна',
#  'разный',
#  'илинуть',
#  'штука',
#  'опция',
#  'неплохо',
#  'карман',
#  'денежный',
#  'дизайн',
#  'прочитать',
#  'лишь',
#  'огонь',
#  'сканировать',
#  'asus',
#  'абсолютно',
#  'обнаружить',
#  'pro',
#  'батарея',
#  'повторно',
#  'переустановка',
#  'чтонуть',
#  'ведь',
#  'остаться',
#  'хрен',
#  'комфортно',
#  'режим',
#  'ура',
#  'звонить',
#  'всякий',
#  'выбор',
#  'приложениян',
#  'рабочий',
#  'заблокировать',
#  'смотреть',
#  'and',
#  'преложение',
#  'начало',
#  'обнова',
#  'надоесть',
#  'совсем',
#  'изменить',
#  'интуитивно',
#  'балл',
#  'нибыть',
#  'придумать',
#  'тоня',
#  'переустановить',
#  'пробовать',
#  'над',
#  'запустить',
#  'сей',
#  'закрываться',
#  'продолжать',
#  'пойти',
#  'защитить',
#  'замечание',
#  'сброс',
#  'закрыть',
#  'чегон',
#  'оченьня',
#  'наш',
#  'приложениевсё',
#  'прошлый',
#  'положить',
#  'люба',
#  'нажимать',
#  'куча',
#  'сменить',
#  'штрих',
#  'набор',
#  'смсон',
#  'работаетний',
#  'узнать',
#  'разрешение',
#  'мешать',
#  'пора',
#  'периодически',
#  'сканирование',
#  'менянета',
#  'flyme',
#  'поменять',
#  'предыдущий',
#  'уровень',
#  'окно',
#  'задолбать',
#  'выполнить',
#  'безний',
#  'увидеть',
#  'функционально',
#  'пишетний',
#  'процент',
#  'попробовать',
#  'жить',
#  'жрать',
#  'везде',
#  'исправно',
#  'кома',
#  'бегать',
#  'совершить',
#  'создавать',
#  'проводить',
#  'большен',
#  'получать',
#  'именно',
#  'чек',
#  'звонок',
#  'модифицированный',
#  'включить',
#  'иначе',
#  'иметься',
#  'предлагать',
#  'еслина',
#  'запускать',
#  'нареканийнуть',
#  'довольно',
#  'снимать',
#  'видимо',
#  'становиться',
#  'корректно',
#  'sony',
#  'стабильный',
#  'наконецтый',
#  'телефонна',
#  'достать',
#  'практически',
#  'приложениемень',
#  'открытие',
#  'контроль',
#  'якобы',
#  'испортить',
#  'качество',
#  'заплатить',
#  'отвечать',
#  'решать',
#  'цель',
#  'galaxy',
#  'аккаунт',
#  'комп',
#  'дерьмо',
#  'приветствие',
#  'заметить',
#  '963',
#  'мера',
#  'многие',
#  'пропадать',
#  'айфон',
#  'владелец',
#  'отсутствовать',
#  'возможный',
#  'зайтина',
#  'мобильно',
#  'вний',
#  'прежний',
#  'сравнение',
#  'никогдан',
#  'вид',
#  'вместо',
#  'короче',
#  'остаток',
#  'коммунальный',
#  'окей',
#  'служба',
#  'разан',
#  'аппарат',
#  'красиво',
#  'исправление',
#  'ещён',
#  'воспользоваться',
#  'ерунда',
#  'искать',
#  'оператор',
#  'привязать',
#  'it',
#  'лёгкое',
#  'вылет',
#  'действительно',
#  'третье',
#  'потерять',
#  'жена',
#  'пусть',
#  'следующий',
#  'правда',
#  'рутом',
#  'тинькофф',
#  'оченьнеудобный',
#  'кошелёк',
#  'подсказать',
#  'удобнобыстро',
#  'фигня',
#  'процесс',
#  'рутправо',
#  'реально',
#  'сб',
#  'ситуация',
#  'её',
#  'пополнение',
#  'телефонный',
#  'скачивание',
#  'штраф',
#  'благодарить',
#  'кредитный',
#  'подряд',
#  'ограничивать',
#  'толькон',
#  'повторить',
#  'rootправо',
#  'ряд',
#  'перед',
#  'устранить',
#  'запрос',
#  'китайский',
#  'оповещение',
#  'введение',
#  'видный',
#  'переустанавливать',
#  'загружать',
#  'qr',
#  'лагаета',
#  'ништяк',
#  'помощник',
#  'отказываться',
#  'быня',
#  'господин',
#  'полноценно',
#  'россия',
#  'шикарно',
#  'просьба',
#  'изменение',
#  'фон',
#  'тп',
#  'медленный',
#  'будто',
#  'программист',
#  'получиться',
#  'техподдержка',
#  'произойти',
#  'вкладка',
#  'надёжный',
#  'внимание',
#  'снести',
#  'около',
#  'желать',
#  'финансовый',
#  'курс',
#  'рутировать',
#  'двойной',
#  'конец',
#  'ресурс',
#  'оставаться',
#  'любить',
#  'lenovo',
#  'этогон',
#  'покупка',
#  'вечно',
#  'появление',
#  '30',
#  'выйти',
#  'сотрудник',
#  'затем',
#  'собираться',
#  'поиск',
#  'девайс',
#  'обращение',
#  'идеально',
#  'слетать',
#  'качественный',
#  'качать',
#  'отстой',
#  'вдруг',
#  'криворукий',
#  'толк',
#  'спрашивать',
#  'рутанета',
#  'чуть',
#  'удобноспасибо',
#  'поступление',
#  '50',
#  'регулярно',
#  'пополнять',
#  'порадовать',
#  'высокий',
#  'производить',
#  'никто',
#  'оч',
#  'провести',
#  'бесконтактный',
#  'безопасный',
#  'уж',
#  'пришлый',
#  'просмотр',
#  'поправить',
#  '7',
#  'урезанный',
#  'функциональный',
#  'понесколька',
#  'единица',
#  'редко',
#  'требоваться',
#  'ноль',
#  'добавлять',
#  'взгляд',
#  'разуна',
#  'перезагружаться',
#  'высота',
#  'правильно',
#  'остановить',
#  'претензия',
#  'доработать',
#  'попасть',
#  'мнение',
#  'спс',
#  'рубль',
#  'мошенник',
#  'перезагрузка',
#  'книга',
#  'основной',
#  'пишитый',
#  'весить',
#  'произвести',
#  'ожидание',
#  'потратить',
#  'антивирусный',
#  'выход',
#  '0',
#  'число',
#  'сохранить',
#  'телефонана',
#  'надпись',
#  'весьма',
#  'удовольствие',
#  'пройти',
#  'находиться',
#  'тратить',
#  'целый',
#  'какна',
#  'забыть',
#  'ранее',
#  'взять',
#  'прислать',
#  'справляться',
#  'электронный',
#  'осуществлять',
#  'досрочно',
#  'ясно',
#  'настроить',
#  'лицензия',
#  'прямо',
#  'похоже',
#  'др',
#  'никуда',
#  'разница',
#  'никакна',
#  'часы',
#  'загрузиться',
#  'цифра',
#  'уметь',
#  'создатель',
#  'никак',
#  'удаваться',
#  'пункт',
#  'твой',
#  'сбрасываться',
#  'твёрдый',
#  '20',
#  'угроза',
#  'списание',
#  'причём',
#  'позвонить',
#  'rootдоступ',
#  'отсутствие',
#  'бонус',
#  '2017',
#  'push',
#  'важный',
#  'полёт',
#  'останавливаться',
#  'брать',
#  'подключиться',
#  'm3s',
#  'подвисать',
#  'htc',
#  'внемой',
#  'иногдан',
#  'облегчать',
#  'способ',
#  'магазин',
#  'включаться',
#  'всенеобходимый',
#  'выскакивать',
#  'ужена',
#  'поход',
#  'приложениеочень',
#  'регион',
#  'зря',
#  'очный',
#  'большинство',
#  'ответить',
#  'рад',
#  'рутованный',
#  'отдельный',
#  'not',
#  ...]

# %%
vocabulary = {v: k for k, v in dict(enumerate(tokens_filtered_top, 1)).items()}

# %%
vocabulary
# Out:
# {'приложение': 1,
#  'весь': 2,
#  'и': 3,
#  'очень': 4,
#  'удобно': 5,
#  'в': 6,
#  'я': 7,
#  'на': 8,
#  'работать': 9,
#  'удобный': 10,
#  'с': 11,
#  'что': 12,
#  'отлично': 13,
#  'спасибо': 14,
#  'нравиться': 15,
#  'хороший': 16,
#  'отличный': 17,
#  'это': 18,
#  'хорошо': 19,
#  'телефон': 20,
#  'по': 21,
#  'супер': 22,
#  'после': 23,
#  'но': 24,
#  'раз': 25,
#  'мочь': 26,
#  'быть': 27,
#  'а': 28,
#  'за': 29,
#  'быстро': 30,
#  'просто': 31,
#  'обновление': 32,
#  'при': 33,
#  'пользоваться': 34,
#  'как': 35,
#  'так': 36,
#  'у': 37,
#  'антивирус': 38,
#  'устраивать': 39,
#  'вы': 40,
#  'сбербанк': 41,
#  'только': 42,
#  'не': 43,
#  'пароль': 44,
#  'пока': 45,
#  'карта': 46,
#  'то': 47,
#  'свой': 48,
#  'нормальный': 49,
#  'для': 50,
#  'прошивка': 51,
#  'вход': 52,
#  'без': 53,
#  'банк': 54,
#  'из': 55,
#  'рута': 56,
#  'перевод': 57,
#  'норма': 58,
#  'есть': 59,
#  'один': 60,
#  'сделать': 61,
#  'программа': 62,
#  'деньга': 63,
#  'разработчик': 64,
#  'счёт': 65,
#  'проблема': 66,
#  'писать': 67,
#  'время': 68,
#  'ошибка': 69,
#  'довольный': 70,
#  'бы': 71,
#  'ваш': 72,
#  'можно': 73,
#  'ок': 74,
#  'платёж': 75,
#  'или': 76,
#  'к': 77,
#  'мой': 78,
#  'он': 79,
#  'до': 80,
#  'стать': 81,
#  'другой': 82,
#  'постоянно': 83,
#  'приходиться': 84,
#  'через': 85,
#  'уже': 86,
#  'два': 87,
#  'понятно': 88,
#  'вводить': 89,
#  'если': 90,
#  'этот': 91,
#  'ещё': 92,
#  'исправить': 93,
#  'надо': 94,
#  'нужно': 95,
#  'тот': 96,
#  'функция': 97,
#  'долго': 98,
#  'код': 99,
#  'ни': 100,
#  'возможность': 101,
#  'такой': 102,
#  'смс': 103,
#  'теперь': 104,
#  'зайти': 105,
#  'большой': 106,
#  'класс': 107,
#  'делать': 108,
#  'мобильный': 109,
#  'право': 110,
#  'последний': 111,
#  'шаблон': 112,
#  'всегда': 113,
#  'какой': 114,
#  'который': 115,
#  'когда': 116,
#  'иня': 117,
#  'вылетать': 118,
#  'самый': 119,
#  'о': 120,
#  'каждый': 121,
#  'приходить': 122,
#  'от': 123,
#  'root': 124,
#  'иногда': 125,
#  'почему': 126,
#  'meizu': 127,
#  'установить': 128,
#  'работа': 129,
#  'проверка': 130,
#  'же': 131,
#  'заходить': 132,
#  'онлайн': 133,
#  'даже': 134,
#  'молодец': 135,
#  'оплата': 136,
#  'нужный': 137,
#  '5': 138,
#  'версия': 139,
#  'операция': 140,
#  'функционал': 141,
#  'банка': 142,
#  'чем': 143,
#  'доступ': 144,
#  'они': 145,
#  'круто': 146,
#  'удалить': 147,
#  'полный': 148,
#  'пожалуйста': 149,
#  'войти': 150,
#  'вообще': 151,
#  'приложениен': 152,
#  'ввод': 153,
#  'номер': 154,
#  'под': 155,
#  'рука': 156,
#  'чтобы': 157,
#  'хотя': 158,
#  'ранний': 159,
#  'клиент': 160,
#  '2': 161,
#  'ян': 162,
#  'понравиться': 163,
#  'изз': 164,
#  'интернет': 165,
#  'день': 166,
#  'легко': 167,
#  'вирус': 168,
#  'целое': 169,
#  'оплачивать': 170,
#  'отпечаток': 171,
#  'зачем': 172,
#  'оно': 173,
#  'дать': 174,
#  'перестать': 175,
#  'кредит': 176,
#  'новый': 177,
#  'первое': 178,
#  'просить': 179,
#  'дом': 180,
#  'много': 181,
#  'выдавать': 182,
#  'запуск': 183,
#  'убрать': 184,
#  'главный': 185,
#  'выходить': 186,
#  'устройство': 187,
#  'простой': 188,
#  'вот': 189,
#  'удалять': 190,
#  'быстрый': 191,
#  'сбер': 192,
#  'сам': 193,
#  'уведомление': 194,
#  'год': 195,
#  'минус': 196,
#  'замечательный': 197,
#  'никакой': 198,
#  'ничегон': 199,
#  'безопасность': 200,
#  'плохо': 201,
#  'оплатить': 202,
#  'сразу': 203,
#  'отзыв': 204,
#  'классный': 205,
#  'знать': 206,
#  'добавить': 207,
#  'ничто': 208,
#  'часто': 209,
#  'перевести': 210,
#  'ждать': 211,
#  'ввести': 212,
#  'доступно': 213,
#  'проверять': 214,
#  'запускаться': 215,
#  'интерфейс': 216,
#  'оригинальный': 217,
#  'дело': 218,
#  'да': 219,
#  'давать': 220,
#  'там': 221,
#  'ну': 222,
#  'банкомат': 223,
#  'открываться': 224,
#  'скачать': 225,
#  'видеть': 226,
#  'кто': 227,
#  'услуга': 228,
#  'палец': 229,
#  'история': 230,
#  'снова': 231,
#  'инициализация': 232,
#  '3': 233,
#  'сообщение': 234,
#  'хотеть': 235,
#  'полезный': 236,
#  'себя': 237,
#  'месяц': 238,
#  'человек': 239,
#  'сервис': 240,
#  'использование': 241,
#  'сейчас': 242,
#  'финансы': 243,
#  'идти': 244,
#  'переводить': 245,
#  '4': 246,
#  'минута': 247,
#  'баланс': 248,
#  'вернуть': 249,
#  'бесполезный': 250,
#  'средство': 251,
#  'управлять': 252,
#  'заново': 253,
#  'любой': 254,
#  'устанавливаться': 255,
#  'андроид': 256,
#  'звезда': 257,
#  'ставить': 258,
#  'долгий': 259,
#  'загружаться': 260,
#  'зависать': 261,
#  'пользователь': 262,
#  'чётко': 263,
#  'тормозить': 264,
#  'думать': 265,
#  'встроить': 266,
#  'классно': 267,
#  'попытка': 268,
#  'общий': 269,
#  'ужасный': 270,
#  'смартфон': 271,
#  'прога': 272,
#  'контакт': 273,
#  'связь': 274,
#  'найти': 275,
#  'прекрасно': 276,
#  '10': 277,
#  'грузиться': 278,
#  'посмотреть': 279,
#  'получаться': 280,
#  'хотеться': 281,
#  'обновить': 282,
#  'вообщен': 283,
#  '1': 284,
#  'гуд': 285,
#  'загрузка': 286,
#  'прийтись': 287,
#  'решить': 288,
#  'сумма': 289,
#  'помогать': 290,
#  'тут': 291,
#  'три': 292,
#  'между': 293,
#  'установка': 294,
#  '24': 295,
#  'куда': 296,
#  'выкидывать': 297,
#  'остальной': 298,
#  'сказать': 299,
#  'бывать': 300,
#  'чтоня': 301,
#  'где': 302,
#  'потом': 303,
#  'далёкий': 304,
#  'кроме': 305,
#  'вроде': 306,
#  'рекомендовать': 307,
#  'ли': 308,
#  'настройка': 309,
#  'входить': 310,
#  'личный': 311,
#  'худой': 312,
#  'здорово': 313,
#  'должный': 314,
#  'понятный': 315,
#  'она': 316,
#  'вопрос': 317,
#  'давно': 318,
#  'надёжно': 319,
#  'возможно': 320,
#  'место': 321,
#  'сайт': 322,
#  'жизнь': 323,
#  'советовать': 324,
#  'ужасно': 325,
#  'стабильно': 326,
#  'регистрация': 327,
#  'система': 328,
#  'бесить': 329,
#  'лишний': 330,
#  'экономить': 331,
#  'тупить': 332,
#  'информация': 333,
#  'дважды': 334,
#  'нона': 335,
#  'требовать': 336,
#  'пин': 337,
#  'мы': 338,
#  'плохой': 339,
#  'пропасть': 340,
#  'вполне': 341,
#  'смочь': 342,
#  'полностью': 343,
#  'оценка': 344,
#  'написать': 345,
#  'опять': 346,
#  'приятно': 347,
#  'начать': 348,
#  'доступный': 349,
#  'разобраться': 350,
#  'предложение': 351,
#  'глючить': 352,
#  'пытаться': 353,
#  'старый': 354,
#  'запрашивать': 355,
#  'чтоб': 356,
#  'нет': 357,
#  'экран': 358,
#  'поставить': 359,
#  'заработать': 360,
#  'появиться': 361,
#  'особенно': 362,
#  'либо': 363,
#  'этоня': 364,
#  'единственный': 365,
#  'ограничение': 366,
#  'выручать': 367,
#  'назад': 368,
#  'сеть': 369,
#  'ругаться': 370,
#  'ужас': 371,
#  'ана': 372,
#  'момент': 373,
#  'постоянный': 374,
#  'отправить': 375,
#  'тоже': 376,
#  'стоить': 377,
#  'потому': 378,
#  'более': 379,
#  'имя': 380,
#  'память': 381,
#  'менять': 382,
#  'тк': 383,
#  'логин': 384,
#  'использовать': 385,
#  'хватать': 386,
#  'смысл': 387,
#  'помочь': 388,
#  'читать': 389,
#  'android': 390,
#  'очередь': 391,
#  'официальный': 392,
#  'кабинет': 393,
#  'удобство': 394,
#  'сбой': 395,
#  'слово': 396,
#  'ребята': 397,
#  'отвратительный': 398,
#  'обновлениян': 399,
#  'раздражать': 400,
#  'данный': 401,
#  'браузер': 402,
#  'устанавливать': 403,
#  'чтоть': 404,
#  'подтверждение': 405,
#  'показывать': 406,
#  'мыть': 407,
#  'огромный': 408,
#  'пять': 409,
#  'приятный': 410,
#  'радовать': 411,
#  'мейза': 412,
#  '6': 413,
#  'бред': 414,
#  'виснуть': 415,
#  'практично': 416,
#  'поэтому': 417,
#  'совершать': 418,
#  'безопасно': 419,
#  'управление': 420,
#  'висеть': 421,
#  'находить': 422,
#  'вклад': 423,
#  'лично': 424,
#  'платить': 425,
#  'покан': 426,
#  'хоть': 427,
#  'многий': 428,
#  'надеяться': 429,
#  'сколько': 430,
#  'соединение': 431,
#  'штрихкод': 432,
#  'сервер': 433,
#  'держать': 434,
#  'отключить': 435,
#  'мало': 436,
#  'открыть': 437,
#  'жаль': 438,
#  'получить': 439,
#  'дажена': 440,
#  'достаточно': 441,
#  'глюк': 442,
#  'samsung': 443,
#  'защита': 444,
#  'обновляться': 445,
#  'почти': 446,
#  'зарегистрироваться': 447,
#  'банковский': 448,
#  'иметь': 449,
#  'копилка': 450,
#  'ходить': 451,
#  'косяк': 452,
#  'говорить': 453,
#  'расход': 454,
#  'уважаемый': 455,
#  'сильно': 456,
#  'равно': 457,
#  'происходить': 458,
#  'список': 459,
#  'проходить': 460,
#  'про': 461,
#  'отображаться': 462,
#  'конечно': 463,
#  'удобнона': 464,
#  'самсунг': 465,
#  'видно': 466,
#  'стоять': 467,
#  'крутой': 468,
#  'note': 469,
#  'набирать': 470,
#  'намного': 471,
#  'ограниченный': 472,
#  'понимать': 473,
#  'жкх': 474,
#  'возникать': 475,
#  'проверить': 476,
#  'good': 477,
#  'оперативно': 478,
#  'планшет': 479,
#  'нарекание': 480,
#  'например': 481,
#  'прекрасный': 482,
#  'кнопка': 483,
#  'ограничить': 484,
#  '100': 485,
#  'появляться': 486,
#  'хрень': 487,
#  'исправлять': 488,
#  'выполнять': 489,
#  'super': 490,
#  'ты': 491,
#  'обслуживание': 492,
#  'тд': 493,
#  'понять': 494,
#  'пользование': 495,
#  'страница': 496,
#  'xiaomi': 497,
#  'сегодня': 498,
#  'принцип': 499,
#  'сидеть': 500,
#  'купить': 501,
#  'обновлять': 502,
#  'случай': 503,
#  'понесколько': 504,
#  'помощь': 505,
#  'сканер': 506,
#  'час': 507,
#  'удаться': 508,
#  'ответ': 509,
#  'занимать': 510,
#  'ok': 511,
#  'действие': 512,
#  'причина': 513,
#  'исправт': 514,
#  'качественно': 515,
#  'какойтый': 516,
#  'итог': 517,
#  'открывать': 518,
#  'подключение': 519,
#  'половина': 520,
#  'создать': 521,
#  'файл': 522,
#  'всего': 523,
#  'пополнить': 524,
#  'погашение': 525,
#  'почемуна': 526,
#  'pay': 527,
#  'проблемень': 528,
#  'наличие': 529,
#  'друг': 530,
#  'пинкод': 531,
#  'грузить': 532,
#  'плюс': 533,
#  'подключить': 534,
#  'скачивать': 535,
#  'начинать': 536,
#  'the': 537,
#  'пара': 538,
#  'redmi': 539,
#  'новое': 540,
#  'тем': 541,
#  'хорошоя': 542,
#  'прошивкан': 543,
#  'тело': 544,
#  'комиссия': 545,
#  'секунда': 546,
#  'удаление': 547,
#  'скачиваться': 548,
#  'повторный': 549,
#  'меню': 550,
#  'слишком': 551,
#  'напрягать': 552,
#  'почемуть': 553,
#  'баг': 554,
#  'открытый': 555,
#  'вещь': 556,
#  'нафиг': 557,
#  'выбрасывать': 558,
#  'заводский': 559,
#  'm5': 560,
#  'здравствовать': 561,
#  '23': 562,
#  'обратно': 563,
#  'простон': 564,
#  'выписка': 565,
#  'отправлять': 566,
#  'скорость': 567,
#  'теперьня': 568,
#  'авторизация': 569,
#  'маленький': 570,
#  'инуть': 571,
#  'разраб': 572,
#  'также': 573,
#  'медленно': 574,
#  'блокировать': 575,
#  'здесь': 576,
#  'квитанция': 577,
#  'считать': 578,
#  'раздел': 579,
#  'тупой': 580,
#  'урезать': 581,
#  'мнен': 582,
#  'тогда': 583,
#  'меняня': 584,
#  'срочно': 585,
#  'автоплатёж': 586,
#  'гораздо': 587,
#  'отделение': 588,
#  'удача': 589,
#  'невозможно': 590,
#  'позволять': 591,
#  'досрочный': 592,
#  'наконец': 593,
#  'исчезнуть': 594,
#  'следить': 595,
#  'добрый': 596,
#  'поддержка': 597,
#  'установленный': 598,
#  'компьютер': 599,
#  'страна': 600,
#  'разный': 601,
#  'илинуть': 602,
#  'штука': 603,
#  'опция': 604,
#  'неплохо': 605,
#  'карман': 606,
#  'денежный': 607,
#  'дизайн': 608,
#  'прочитать': 609,
#  'лишь': 610,
#  'огонь': 611,
#  'сканировать': 612,
#  'asus': 613,
#  'абсолютно': 614,
#  'обнаружить': 615,
#  'pro': 616,
#  'батарея': 617,
#  'повторно': 618,
#  'переустановка': 619,
#  'чтонуть': 620,
#  'ведь': 621,
#  'остаться': 622,
#  'хрен': 623,
#  'комфортно': 624,
#  'режим': 625,
#  'ура': 626,
#  'звонить': 627,
#  'всякий': 628,
#  'выбор': 629,
#  'приложениян': 630,
#  'рабочий': 631,
#  'заблокировать': 632,
#  'смотреть': 633,
#  'and': 634,
#  'преложение': 635,
#  'начало': 636,
#  'обнова': 637,
#  'надоесть': 638,
#  'совсем': 639,
#  'изменить': 640,
#  'интуитивно': 641,
#  'балл': 642,
#  'нибыть': 643,
#  'придумать': 644,
#  'тоня': 645,
#  'переустановить': 646,
#  'пробовать': 647,
#  'над': 648,
#  'запустить': 649,
#  'сей': 650,
#  'закрываться': 651,
#  'продолжать': 652,
#  'пойти': 653,
#  'защитить': 654,
#  'замечание': 655,
#  'сброс': 656,
#  'закрыть': 657,
#  'чегон': 658,
#  'оченьня': 659,
#  'наш': 660,
#  'приложениевсё': 661,
#  'прошлый': 662,
#  'положить': 663,
#  'люба': 664,
#  'нажимать': 665,
#  'куча': 666,
#  'сменить': 667,
#  'штрих': 668,
#  'набор': 669,
#  'смсон': 670,
#  'работаетний': 671,
#  'узнать': 672,
#  'разрешение': 673,
#  'мешать': 674,
#  'пора': 675,
#  'периодически': 676,
#  'сканирование': 677,
#  'менянета': 678,
#  'flyme': 679,
#  'поменять': 680,
#  'предыдущий': 681,
#  'уровень': 682,
#  'окно': 683,
#  'задолбать': 684,
#  'выполнить': 685,
#  'безний': 686,
#  'увидеть': 687,
#  'функционально': 688,
#  'пишетний': 689,
#  'процент': 690,
#  'попробовать': 691,
#  'жить': 692,
#  'жрать': 693,
#  'везде': 694,
#  'исправно': 695,
#  'кома': 696,
#  'бегать': 697,
#  'совершить': 698,
#  'создавать': 699,
#  'проводить': 700,
#  'большен': 701,
#  'получать': 702,
#  'именно': 703,
#  'чек': 704,
#  'звонок': 705,
#  'модифицированный': 706,
#  'включить': 707,
#  'иначе': 708,
#  'иметься': 709,
#  'предлагать': 710,
#  'еслина': 711,
#  'запускать': 712,
#  'нареканийнуть': 713,
#  'довольно': 714,
#  'снимать': 715,
#  'видимо': 716,
#  'становиться': 717,
#  'корректно': 718,
#  'sony': 719,
#  'стабильный': 720,
#  'наконецтый': 721,
#  'телефонна': 722,
#  'достать': 723,
#  'практически': 724,
#  'приложениемень': 725,
#  'открытие': 726,
#  'контроль': 727,
#  'якобы': 728,
#  'испортить': 729,
#  'качество': 730,
#  'заплатить': 731,
#  'отвечать': 732,
#  'решать': 733,
#  'цель': 734,
#  'galaxy': 735,
#  'аккаунт': 736,
#  'комп': 737,
#  'дерьмо': 738,
#  'приветствие': 739,
#  'заметить': 740,
#  '963': 741,
#  'мера': 742,
#  'многие': 743,
#  'пропадать': 744,
#  'айфон': 745,
#  'владелец': 746,
#  'отсутствовать': 747,
#  'возможный': 748,
#  'зайтина': 749,
#  'мобильно': 750,
#  'вний': 751,
#  'прежний': 752,
#  'сравнение': 753,
#  'никогдан': 754,
#  'вид': 755,
#  'вместо': 756,
#  'короче': 757,
#  'остаток': 758,
#  'коммунальный': 759,
#  'окей': 760,
#  'служба': 761,
#  'разан': 762,
#  'аппарат': 763,
#  'красиво': 764,
#  'исправление': 765,
#  'ещён': 766,
#  'воспользоваться': 767,
#  'ерунда': 768,
#  'искать': 769,
#  'оператор': 770,
#  'привязать': 771,
#  'it': 772,
#  'лёгкое': 773,
#  'вылет': 774,
#  'действительно': 775,
#  'третье': 776,
#  'потерять': 777,
#  'жена': 778,
#  'пусть': 779,
#  'следующий': 780,
#  'правда': 781,
#  'рутом': 782,
#  'тинькофф': 783,
#  'оченьнеудобный': 784,
#  'кошелёк': 785,
#  'подсказать': 786,
#  'удобнобыстро': 787,
#  'фигня': 788,
#  'процесс': 789,
#  'рутправо': 790,
#  'реально': 791,
#  'сб': 792,
#  'ситуация': 793,
#  'её': 794,
#  'пополнение': 795,
#  'телефонный': 796,
#  'скачивание': 797,
#  'штраф': 798,
#  'благодарить': 799,
#  'кредитный': 800,
#  'подряд': 801,
#  'ограничивать': 802,
#  'толькон': 803,
#  'повторить': 804,
#  'rootправо': 805,
#  'ряд': 806,
#  'перед': 807,
#  'устранить': 808,
#  'запрос': 809,
#  'китайский': 810,
#  'оповещение': 811,
#  'введение': 812,
#  'видный': 813,
#  'переустанавливать': 814,
#  'загружать': 815,
#  'qr': 816,
#  'лагаета': 817,
#  'ништяк': 818,
#  'помощник': 819,
#  'отказываться': 820,
#  'быня': 821,
#  'господин': 822,
#  'полноценно': 823,
#  'россия': 824,
#  'шикарно': 825,
#  'просьба': 826,
#  'изменение': 827,
#  'фон': 828,
#  'тп': 829,
#  'медленный': 830,
#  'будто': 831,
#  'программист': 832,
#  'получиться': 833,
#  'техподдержка': 834,
#  'произойти': 835,
#  'вкладка': 836,
#  'надёжный': 837,
#  'внимание': 838,
#  'снести': 839,
#  'около': 840,
#  'желать': 841,
#  'финансовый': 842,
#  'курс': 843,
#  'рутировать': 844,
#  'двойной': 845,
#  'конец': 846,
#  'ресурс': 847,
#  'оставаться': 848,
#  'любить': 849,
#  'lenovo': 850,
#  'этогон': 851,
#  'покупка': 852,
#  'вечно': 853,
#  'появление': 854,
#  '30': 855,
#  'выйти': 856,
#  'сотрудник': 857,
#  'затем': 858,
#  'собираться': 859,
#  'поиск': 860,
#  'девайс': 861,
#  'обращение': 862,
#  'идеально': 863,
#  'слетать': 864,
#  'качественный': 865,
#  'качать': 866,
#  'отстой': 867,
#  'вдруг': 868,
#  'криворукий': 869,
#  'толк': 870,
#  'спрашивать': 871,
#  'рутанета': 872,
#  'чуть': 873,
#  'удобноспасибо': 874,
#  'поступление': 875,
#  '50': 876,
#  'регулярно': 877,
#  'пополнять': 878,
#  'порадовать': 879,
#  'высокий': 880,
#  'производить': 881,
#  'никто': 882,
#  'оч': 883,
#  'провести': 884,
#  'бесконтактный': 885,
#  'безопасный': 886,
#  'уж': 887,
#  'пришлый': 888,
#  'просмотр': 889,
#  'поправить': 890,
#  '7': 891,
#  'урезанный': 892,
#  'функциональный': 893,
#  'понесколька': 894,
#  'единица': 895,
#  'редко': 896,
#  'требоваться': 897,
#  'ноль': 898,
#  'добавлять': 899,
#  'взгляд': 900,
#  'разуна': 901,
#  'перезагружаться': 902,
#  'высота': 903,
#  'правильно': 904,
#  'остановить': 905,
#  'претензия': 906,
#  'доработать': 907,
#  'попасть': 908,
#  'мнение': 909,
#  'спс': 910,
#  'рубль': 911,
#  'мошенник': 912,
#  'перезагрузка': 913,
#  'книга': 914,
#  'основной': 915,
#  'пишитый': 916,
#  'весить': 917,
#  'произвести': 918,
#  'ожидание': 919,
#  'потратить': 920,
#  'антивирусный': 921,
#  'выход': 922,
#  '0': 923,
#  'число': 924,
#  'сохранить': 925,
#  'телефонана': 926,
#  'надпись': 927,
#  'весьма': 928,
#  'удовольствие': 929,
#  'пройти': 930,
#  'находиться': 931,
#  'тратить': 932,
#  'целый': 933,
#  'какна': 934,
#  'забыть': 935,
#  'ранее': 936,
#  'взять': 937,
#  'прислать': 938,
#  'справляться': 939,
#  'электронный': 940,
#  'осуществлять': 941,
#  'досрочно': 942,
#  'ясно': 943,
#  'настроить': 944,
#  'лицензия': 945,
#  'прямо': 946,
#  'похоже': 947,
#  'др': 948,
#  'никуда': 949,
#  'разница': 950,
#  'никакна': 951,
#  'часы': 952,
#  'загрузиться': 953,
#  'цифра': 954,
#  'уметь': 955,
#  'создатель': 956,
#  'никак': 957,
#  'удаваться': 958,
#  'пункт': 959,
#  'твой': 960,
#  'сбрасываться': 961,
#  'твёрдый': 962,
#  '20': 963,
#  'угроза': 964,
#  'списание': 965,
#  'причём': 966,
#  'позвонить': 967,
#  'rootдоступ': 968,
#  'отсутствие': 969,
#  'бонус': 970,
#  '2017': 971,
#  'push': 972,
#  'важный': 973,
#  'полёт': 974,
#  'останавливаться': 975,
#  'брать': 976,
#  'подключиться': 977,
#  'm3s': 978,
#  'подвисать': 979,
#  'htc': 980,
#  'внемой': 981,
#  'иногдан': 982,
#  'облегчать': 983,
#  'способ': 984,
#  'магазин': 985,
#  'включаться': 986,
#  'всенеобходимый': 987,
#  'выскакивать': 988,
#  'ужена': 989,
#  'поход': 990,
#  'приложениеочень': 991,
#  'регион': 992,
#  'зря': 993,
#  'очный': 994,
#  'большинство': 995,
#  'ответить': 996,
#  'рад': 997,
#  'рутованный': 998,
#  'отдельный': 999,
#  'not': 1000,
#  ...}

# %%
def text_to_sequence(text, maxlen):
    result = []
    tokens = word_tokenize(text.lower())
    tokens_filtered = [word for word in tokens if word.isalnum()]
    for word in tokens_filtered:
        if word in vocabulary:
            result.append(vocabulary[word])
    padding = [0]*(maxlen-len(result))
    return padding + result[-maxlen:]

# %%
x_train = np.asarray([text_to_sequence(text, max_len) for text in X_train], dtype=np.int32)
x_test = np.asarray([text_to_sequence(text, max_len) for text in X_test], dtype=np.int32)

# %%
x_train
# Out:
# array([[  0,   0,   0, ...,   0,   0, 267],
#        [  0,   0,   0, ...,   8, 998,  20],
#        [  0,   0,   0, ...,  19,  53, 480],
#        ...,
#        [  0,   0,   0, ...,   0,   0,   5],
#        [  0,   0,   0, ...,   0,   0,  22],
#        [  0,   0,   0, ...,   0,   2,  19]], dtype=int32)

# %%
num_classes = 2
y_train = keras.utils.to_categorical(y_train, num_classes)
y_val = keras.utils.to_categorical(y_test, num_classes)

# %%
model = Sequential()
model.add(Embedding(input_dim=max_words, output_dim=128, input_length=max_len))
model.add(Conv1D(128, 3))
model.add(Activation("relu"))
model.add(GlobalMaxPool1D())
model.add(Dense(10))
model.add(Activation("relu"))
model.add(Dense(num_classes))
model.add(Activation('softmax'))
# Out:
# WARNING:tensorflow:From /home/alex/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
tensorboard=TensorBoard(log_dir='./logs', write_graph=True, write_images=True)
early_stopping=EarlyStopping(monitor='val_loss')  


history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_split=0.1,
                    callbacks=[tensorboard, early_stopping])
# Out:
# WARNING:tensorflow:From /home/alex/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 14218 samples, validate on 1580 samples
# WARNING:tensorflow:From /home/alex/anaconda3/lib/python3.7/site-packages/keras/callbacks/tensorboard_v1.py:200: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /home/alex/anaconda3/lib/python3.7/site-packages/keras/callbacks/tensorboard_v1.py:203: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Epoch 1/20
# 14218/14218 [==============================] - 2s 137us/step - loss: 0.4516 - accuracy: 0.8285 - val_loss: 0.3371 - val_accuracy: 0.8456
# WARNING:tensorflow:From /home/alex/anaconda3/lib/python3.7/site-packages/keras/callbacks/tensorboard_v1.py:343: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# Epoch 2/20
# 14218/14218 [==============================] - 2s 122us/step - loss: 0.2637 - accuracy: 0.8787 - val_loss: 0.2030 - val_accuracy: 0.9095
# Epoch 3/20
# 14218/14218 [==============================] - 2s 122us/step - loss: 0.1784 - accuracy: 0.9278 - val_loss: 0.1734 - val_accuracy: 0.9190
# Epoch 4/20
# 14218/14218 [==============================] - 2s 130us/step - loss: 0.1434 - accuracy: 0.9444 - val_loss: 0.1680 - val_accuracy: 0.9241
# Epoch 5/20
# 14218/14218 [==============================] - 2s 130us/step - loss: 0.1248 - accuracy: 0.9525 - val_loss: 0.1767 - val_accuracy: 0.9215

# %%
score = model.evaluate(x_test, y_val, batch_size=batch_size, verbose=1)
print('\n')
print('Test score:', score[0])
print('Test accuracy:', score[1])
# Out:
# 3950/3950 [==============================] - 0s 38us/step
#
#
# Test score: 0.16928679318367681
# Test accuracy: 0.9255695939064026

# %%
results = model.predict(x_test, batch_size=batch_size, verbose=1)
# Out:
# 3950/3950 [==============================] - 0s 47us/step

# %%
roc_auc_score(y_test, results[:, 1])
# Out:
# 0.9664220682157901

# %% [markdown]
# # 2

# %%
from gensim.models import Word2Vec

# %%
sentences = X_train.apply(lambda x: x.split())

# %%
sentences.values
# Out:
# array([list(['классно']),
#        list(['невозможно', 'использовать', 'на', 'рутованный', 'телефон']),
#        list(['работать', 'хорошо', 'без', 'нарекание']), ...,
#        list(['удобно']), list(['супер']), list(['весь', 'хорошо'])],
#       dtype=object)

# %%
modelW2V = Word2Vec(sentences=sentences.values, size=128, window=5, min_count=1)

# %%
modelW2V.syn1neg[:max_words].shape
# Out:
# /home/alex/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `syn1neg` (Attribute will be removed in 4.0.0, use self.trainables.syn1neg instead).
#   """Entry point for launching an IPython kernel.
# (2000, 128)

# %%
model = Sequential()
model.add(Embedding(input_dim=max_words, output_dim=128,
                    input_length=max_len, weights=[modelW2V.syn1neg[:max_words]], trainable=False))
model.add(Conv1D(128, 3))
model.add(Activation("relu"))
model.add(GlobalMaxPool1D())
model.add(Dense(10))
model.add(Activation("relu"))
model.add(Dense(num_classes))
model.add(Activation('softmax'))
# Out:
# /home/alex/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `syn1neg` (Attribute will be removed in 4.0.0, use self.trainables.syn1neg instead).

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
tensorboard=TensorBoard(log_dir='./logs', write_graph=True, write_images=True)
early_stopping=EarlyStopping(monitor='val_loss')  


history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_split=0.1,
                    callbacks=[tensorboard, early_stopping])
# Out:
# Train on 14218 samples, validate on 1580 samples
# Epoch 1/20
# 14218/14218 [==============================] - 1s 82us/step - loss: 0.3922 - accuracy: 0.8481 - val_loss: 0.3182 - val_accuracy: 0.8551
# Epoch 2/20
# 14218/14218 [==============================] - 1s 76us/step - loss: 0.3090 - accuracy: 0.8584 - val_loss: 0.3028 - val_accuracy: 0.8557
# Epoch 3/20
# 14218/14218 [==============================] - 1s 77us/step - loss: 0.2984 - accuracy: 0.8653 - val_loss: 0.2942 - val_accuracy: 0.8557
# Epoch 4/20
# 14218/14218 [==============================] - 1s 68us/step - loss: 0.2911 - accuracy: 0.8682 - val_loss: 0.2874 - val_accuracy: 0.8614
# Epoch 5/20
# 14218/14218 [==============================] - 1s 63us/step - loss: 0.2844 - accuracy: 0.8745 - val_loss: 0.2823 - val_accuracy: 0.8620
# Epoch 6/20
# 14218/14218 [==============================] - 1s 64us/step - loss: 0.2778 - accuracy: 0.8772 - val_loss: 0.2762 - val_accuracy: 0.8595
# Epoch 7/20
# 14218/14218 [==============================] - 1s 63us/step - loss: 0.2723 - accuracy: 0.8787 - val_loss: 0.2715 - val_accuracy: 0.8620
# Epoch 8/20
# 14218/14218 [==============================] - 1s 66us/step - loss: 0.2691 - accuracy: 0.8808 - val_loss: 0.2671 - val_accuracy: 0.8614
# Epoch 9/20
# 14218/14218 [==============================] - 1s 64us/step - loss: 0.2640 - accuracy: 0.8837 - val_loss: 0.2630 - val_accuracy: 0.8677
# Epoch 10/20
# 14218/14218 [==============================] - 1s 63us/step - loss: 0.2611 - accuracy: 0.8852 - val_loss: 0.2624 - val_accuracy: 0.8671
# Epoch 11/20
# 14218/14218 [==============================] - 1s 70us/step - loss: 0.2593 - accuracy: 0.8854 - val_loss: 0.2690 - val_accuracy: 0.8741

# %%
results = model.predict(x_test, batch_size=batch_size, verbose=1)
# Out:
# 3950/3950 [==============================] - 0s 38us/step

# %%
roc_auc_score(y_test, results[:, 1])
# Out:
# 0.9076013292319856

# %% [markdown]
# При инициализации эмбеддинга предобучеными весами, модель показывает худшее качество

# %%
model = Sequential()
model.add(Embedding(input_dim=max_words, output_dim=128,
                    input_length=max_len, weights=[modelW2V.syn1neg[:max_words]]))
model.add(Conv1D(128, 3))
model.add(Activation("relu"))
model.add(GlobalMaxPool1D())
model.add(Dense(10))
model.add(Activation("relu"))
model.add(Dense(num_classes))
model.add(Activation('softmax'))
# Out:
# /home/alex/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `syn1neg` (Attribute will be removed in 4.0.0, use self.trainables.syn1neg instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
tensorboard=TensorBoard(log_dir='./logs', write_graph=True, write_images=True)
early_stopping=EarlyStopping(monitor='val_loss')  


history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_split=0.1,
                    callbacks=[tensorboard, early_stopping])
# Out:
# Train on 14218 samples, validate on 1580 samples
# Epoch 1/20
# 14218/14218 [==============================] - 1s 100us/step - loss: 0.3931 - accuracy: 0.8506 - val_loss: 0.3026 - val_accuracy: 0.8646
# Epoch 2/20
# 14218/14218 [==============================] - 1s 90us/step - loss: 0.2737 - accuracy: 0.8789 - val_loss: 0.2511 - val_accuracy: 0.8892
# Epoch 3/20
# 14218/14218 [==============================] - 1s 89us/step - loss: 0.2207 - accuracy: 0.9069 - val_loss: 0.2014 - val_accuracy: 0.9013
# Epoch 4/20
# 14218/14218 [==============================] - 1s 88us/step - loss: 0.1721 - accuracy: 0.9290 - val_loss: 0.1725 - val_accuracy: 0.9222
# Epoch 5/20
# 14218/14218 [==============================] - 1s 91us/step - loss: 0.1412 - accuracy: 0.9451 - val_loss: 0.1668 - val_accuracy: 0.9234
# Epoch 6/20
# 14218/14218 [==============================] - 1s 98us/step - loss: 0.1223 - accuracy: 0.9526 - val_loss: 0.1695 - val_accuracy: 0.9253

# %%
results = model.predict(x_test, batch_size=batch_size, verbose=1)
# Out:
# 3950/3950 [==============================] - 0s 43us/step

# %%
roc_auc_score(y_test, results[:, 1])
# Out:
# 0.9683136295692351

# %% [markdown]
# Однако, если использовать их только как отправную точку, и позволить модели их обучать, то на выходе получается качество, несколько выше чем при случайной инициализации.
